# %%
import numpy as np
import tensorflow as tf

# %%
input_dim = 15
weight_scale=1e-2
hidden_dims = [12, 10, 5]
num_layers = len(hidden_dims) + 1
classes = 2

params = {'W' + str(y + 2) : np.random.normal(scale = weight_scale, size = (hidden_dims[y], hidden_dims[y + 1])) for y in range(num_layers - 2)}
params['W1'] = np.random.normal(0, weight_scale, (input_dim, hidden_dims[0]))
params['W' + str(num_layers)] = np.random.normal(0, weight_scale, (hidden_dims[-1], classes))
params['W1'] = 0
params
# Out:
# {'W1': 0, 'W2': array([[  1.66963761e-02,   8.67616756e-03,   4.71995429e-04,
#            2.42536969e-03,   1.25587763e-02,  -3.39522562e-03,
#           -3.55279672e-03,  -1.56154913e-03,   4.77257782e-04,
#           -5.35544191e-03],
#         [  4.53247754e-04,  -4.38985905e-03,   1.31588709e-02,
#            1.42114379e-02,   1.22038568e-02,   7.94416019e-03,
#            1.06379529e-02,  -1.38684050e-02,  -2.28728794e-02,
#            1.40431301e-03],
#         [ -4.60688459e-03,  -3.49468268e-03,   3.62854602e-03,
#            9.66469766e-04,  -9.02920999e-03,   5.10710167e-04,
#            1.15485590e-03,   1.02628905e-02,  -9.78693179e-03,
#           -9.43913964e-04],
#         [  6.10510430e-03,   1.44365503e-02,  -4.48797585e-03,
#           -7.41626070e-03,  -2.72870479e-02,  -1.14306756e-02,
#           -1.08831865e-02,   2.36532687e-03,   4.87721179e-03,
#            1.01451157e-02],
#         [  1.44236446e-02,   7.47447943e-03,  -4.46582361e-03,
# ...

# %%
x = np.arange(6).reshape((3,2))
x
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
y = np.mean(x, axis =0)
y
# Out:
# array([ 2.,  3.])

# %%
x*x
# Out:
# array([[ 0,  1],
#        [ 4,  9],
#        [16, 25]])
